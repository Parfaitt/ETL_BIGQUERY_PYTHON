# %%
from google.cloud import bigquery
import os


# ===================== CONFIGURATION =====================
PROJECT_ID = "iron-arbor-432008-r7"
DATASET_ID = "Pmt_2026"
CSV_FOLDER = "D:\RECO\PROJECT 2026\BIG QUERY PROJECT\DATASET"

# Chaque fichier correspond à une table BigQuery
FILES = [
    "account",
    "card",
    "client",
    "disp",
    "district",
    "loan",
    "orders",
    "trans"
]

# =========================================================


# Création du client BigQuery (authentification via service account ou ADC)
client = bigquery.Client(project=PROJECT_ID)


# Configuration du job de chargement
job_config = bigquery.LoadJobConfig(
    source_format=bigquery.SourceFormat.CSV,  # Format source : CSV
    skip_leading_rows=1,                      # Ignore la première ligne (header)
    autodetect=True,                          # Détection automatique du schéma
    write_disposition="WRITE_TRUNCATE"        # Remplace la table si elle existe
)


# Boucle sur chaque fichier CSV
for table in FILES:

    # Construction du chemin vers le fichier CSV
    csv_path = os.path.join(CSV_FOLDER, f"{table}.csv")

    # Construction de l'identifiant complet de la table BigQuery
    # Format : projet.dataset.table
    table_id = f"{PROJECT_ID}.{DATASET_ID}.{table}"

    # Log du chargement en cours
    print(f"📥 Chargement {csv_path} → {table_id}")

    # Ouverture du fichier CSV en mode binaire
    with open(csv_path, "rb") as f:

        # Lancement du job de chargement vers BigQuery
        job = client.load_table_from_file(
            f,
            table_id,
            job_config=job_config
        )

    # Attente de la fin du job (bloquant)
    job.result()

    # Confirmation du chargement
    print(f"✅ Table {table} créée avec succès")


# Message final après chargement de tous les fichiers
print("🚀 Toutes les tables ont été chargées avec succès")
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\R'
# <>:8: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\Tanoh Parfait\AppData\Local\Temp\ipykernel_110152\3506813740.py:8: SyntaxWarning: invalid escape sequence '\R'
#   CSV_FOLDER = "D:\RECO\PROJECT 2026\BIG QUERY PROJECT\DATASET"
# 📥 Chargement D:\RECO\PROJECT 2026\BIG QUERY PROJECT\DATASET\account.csv → iron-arbor-432008-r7.mon_dataset.account
# C:\Users\Tanoh Parfait\AppData\Local\Temp\ipykernel_110152\3506813740.py:8: SyntaxWarning: invalid escape sequence '\R'
#   CSV_FOLDER = "D:\RECO\PROJECT 2026\BIG QUERY PROJECT\DATASET"
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\client.py:2599, in Client.load_table_from_file(self, file_obj, destination, rewind, size, num_retries, job_id, job_id_prefix, location, project, job_config, timeout)
#    2598 if size is None or size >= _MAX_MULTIPART_SIZE:
# -> 2599     response = self._do_resumable_upload(
#    2600         file_obj, job_resource, num_retries, timeout, project=project
#    2601     )
#    2602 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\client.py:3019, in Client._do_resumable_upload(self, stream, metadata, num_retries, timeout, project)
#    2996 """Perform a resumable upload.
#    2997
#    2998 Args:
#    (...)
#    3017     is uploaded.
#    3018 """
# -> 3019 upload, transport = self._initiate_resumable_upload(
#    3020     stream, metadata, num_retries, timeout, project=project
#    3021 )
#    3023 while not upload.finished:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\client.py:3088, in Client._initiate_resumable_upload(self, stream, metadata, num_retries, timeout, project)
#    3084     upload._retry_strategy = resumable_media.RetryStrategy(
#    3085         max_retries=num_retries
#    3086     )
# -> 3088 upload.initiate(
#    3089     transport,
#    3090     stream,
#    3091     metadata,
#    3092     _GENERIC_CONTENT_TYPE,
#    3093     stream_final=False,
#    3094     timeout=timeout,
#    3095 )
#    3097 return upload, transport
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\resumable_media\requests\upload.py:420, in ResumableUpload.initiate(self, transport, stream, metadata, content_type, total_bytes, stream_final, timeout)
#     418     return result
# --> 420 return _request_helpers.wait_and_retry(
#     421     retriable_request, self._get_status_code, self._retry_strategy
#     422 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\resumable_media\requests\_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\resumable_media\requests\upload.py:416, in ResumableUpload.initiate.<locals>.retriable_request()
#     412 result = transport.request(
#     413     method, url, data=payload, headers=headers, timeout=timeout
#     414 )
# --> 416 self._process_initiate_response(result)
#     418 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\resumable_media\_upload.py:518, in ResumableUpload._process_initiate_response(self, response)
#     503 """Process the response from an HTTP request that initiated upload.
#     504
#     505 This is everything that must be done after a request that doesn't
#    (...)
#     516 .. _sans-I/O: https://sans-io.readthedocs.io/
#     517 """
# --> 518 _helpers.require_status_code(
#     519     response,
#     520     (http.client.OK, http.client.CREATED),
#     521     self._get_status_code,
#     522     callback=self._make_invalid,
#     523 )
#     524 self._resumable_url = _helpers.header_required(
#     525     response, "location", self._get_headers
#     526 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\resumable_media\_helpers.py:108, in require_status_code(response, status_codes, get_status_code, callback)
#     107         callback()
# --> 108     raise common.InvalidResponse(
#     109         response,
#     110         "Request failed with status code",
#     111         status_code,
#     112         "Expected one of",
#     113         *status_codes
#     114     )
#     115 return status_code
#
# InvalidResponse: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.CREATED: 201>)
#
# During handling of the above exception, another exception occurred:
#
# NotFound                                  Traceback (most recent call last)
# Cell In[3], line 55
#      51 # Ouverture du fichier CSV en mode binaire
#      52 with open(csv_path, "rb") as f:
#      53
#      54     # Lancement du job de chargement vers BigQuery
# ---> 55     job = client.load_table_from_file(
#      56         f,
#      57         table_id,
#      58         job_config=job_config
#      59     )
#      61 # Attente de la fin du job (bloquant)
#      62 job.result()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\client.py:2607, in Client.load_table_from_file(self, file_obj, destination, rewind, size, num_retries, job_id, job_id_prefix, location, project, job_config, timeout)
#    2603         response = self._do_multipart_upload(
#    2604             file_obj, job_resource, size, num_retries, timeout, project=project
#    2605         )
#    2606 except resumable_media.InvalidResponse as exc:
# -> 2607     raise exceptions.from_http_response(exc.response)
#    2609 return typing.cast(LoadJob, self.job_from_resource(response.json()))
#
# NotFound: 404 POST https://bigquery.googleapis.com/upload/bigquery/v2/projects/iron-arbor-432008-r7/jobs?uploadType=resumable: Not found: Dataset iron-arbor-432008-r7:mon_dataset
